# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
sample_submission=pd.read_csv('../data/sample_submission.csv')
store = pd.read_csv('../data/sample_submission.csv')
test = pd.read_csv('../data/test.csv')
train = pd.read_csv('../data/train.csv')
# Out:
# /var/folders/8d/kl24b_0s3gx0jhkqll61_jmm0000gn/T/ipykernel_38663/87389638.py:4: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   train = pd.read_csv('../data/train.csv')

# %%
store.head()
# Out:
#    Id  Sales
# 0   1      0
# 1   2      0
# 2   3      0
# 3   4      0
# 4   5      0

# %%
test.head()
# Out:
#    Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday
# 0   1      1          4  2015-09-17   1.0      1            0              0
# 1   2      3          4  2015-09-17   1.0      1            0              0
# 2   3      7          4  2015-09-17   1.0      1            0              0
# 3   4      8          4  2015-09-17   1.0      1            0              0
# 4   5      9          4  2015-09-17   1.0      1            0              0

# %%
train.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
sample_submission.head()
# Out:
#    Id  Sales
# 0   1      0
# 1   2      0
# 2   3      0
# 3   4      0
# 4   5      0

# %%
import logging

# %%
from scripts.task_1 import EDA
from scripts.task_2 import Task2
# Define file paths
data_paths = {
    'sample_submission': '../data/sample_submission.csv',
    'store': '../data/store.csv',
    'test': '../data/test.csv',
    'train': '../data/train.csv'
}
# Initialize and run EDA
task = Task2(data_paths)
task.run_pipeline()
task.split_the_dataset()
task.data_preprocessing()
predictions = task.choose_model()
logging.info(f"Predictions saved: {predictions[:10]}")
# # Create an instance of the class
# eda = EDA(data_paths)

# # Run the pipeline
# eda.run_pipeline()

# # File paths
#     paths = {
#         'train': 'train.csv',
#         'test': 'test.csv',
#         'store': 'store.csv',
#         'sample_submission': 'sample_submission.csv'
#     }

#     # Initialize and run EDA
#     task = Task2(paths)
#     task.run_pipeline()
#     task.split_the_dataset()
#     task.data_preprocessing()
#     predictions = task.choose_model()
#     logging.info(f"Predictions saved: {predictions[:10]}")
# Out:
# /Users/senaiahderom/Documents/10Academy-kifya/week-4/scripts/task_1.py:31: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.train = pd.read_csv(self.data_paths['train'])
# 2025-01-14 15:03:32,464 - INFO - Data loaded successfully.
# 2025-01-14 15:03:32,699 - INFO - Data merged successfully.
# /Users/senaiahderom/Documents/10Academy-kifya/week-4/scripts/task_1.py:45: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# ...

# %%
# df = pd.DataFrame(data)
# df = preprocess_data(df)
# print(df.head())
